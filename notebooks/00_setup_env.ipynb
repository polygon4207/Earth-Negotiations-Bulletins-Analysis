# %%
import os

# %%
os.makedirs("../data/csv_entities", exist_ok=True)
os.makedirs("../data/pdf_data", exist_ok=True)
os.makedirs("../data/txt_blocks", exist_ok=True)
os.makedirs("../data/txt_data", exist_ok=True)
os.makedirs("../data/txt_sentences", exist_ok=True)
